# %%
from bs4 import BeautifulSoup
import urllib.request
import numpy as np
import pandas as pd
import re
import helper_functions as hf

# %% [markdown]
# ## Get tournament teams

# %% [markdown]
# Because this script takes a while to run, I only want to scrape for teams that were in the tournament in a given year (our training set).

# %%
seeds_all = pd.read_csv('data/kaggle_data/MNCAATourneySeeds.csv')
seeds = seeds_all[seeds_all['Season'] >= 2003]

# %%
seeds.head()
# Out:
#       Season Seed  TeamID
# 1154    2003  W01    1328
# 1155    2003  W02    1448
# 1156    2003  W03    1393
# 1157    2003  W04    1257
# 1158    2003  W05    1280

# %%
team_spellings = pd.read_csv('data/kaggle_data/MTeamSpellings.csv')

# %%
team_table = seeds.merge(team_spellings, on=['TeamID'])

# %%
team_names = team_table[team_table['Season'] == 2021]['TeamNameSpelling']

# %%
yr = 2021
seeds_all = pd.read_csv('data/kaggle_data/MNCAATourneySeeds.csv')
team_spellings = pd.read_csv('data/kaggle_data/MTeamSpellings.csv')
team_table = seeds.merge(team_spellings, on=['TeamID'])
tourney_team_names = list(team_table[team_table['Season'] == yr]['TeamNameSpelling'])
tourney_team_names
# Out:
# ['oklahoma',
#  'syracuse',
#  'oklahoma st',
#  'oklahoma st.',
#  'oklahoma state',
#  'oklahoma-st',
#  'oklahoma-state',
#  'texas',
#  'florida',
#  'connecticut',
#  'uconn',
#  'maryland',
#  'michigan st',
#  'michigan st.',
#  'michigan state',
#  'michigan-st',
#  'michigan-state',
#  'louisiana state',
#  'louisiana-state',
#  'lsu',
#  'purdue',
#  'colorado',
#  'brigham young',
#  'brigham-young',
#  'byu',
#  'texas southern',
#  'texas-southern',
#  'tx southern',
#  'wisconsin',
#  'missouri',
#  'oregon',
#  'alabama',
#  'kansas',
#  'illinois',
#  'creighton',
#  'gonzaga',
#  'utah st',
#  'utah st.',
#  'utah state',
#  'utah-st',
#  'utah-state',
#  'north carolina',
#  'north-carolina',
#  'unc',
#  'texas tech',
#  'texas-tech',
#  'va commonwealth',
#  'vcu',
#  'vcu(va. commonwealth',
#  'virginia commonwealth',
#  'virginia-commonwealth',
#  'e washington',
#  'eastern wash.',
#  'eastern washington',
#  'eastern-wash',
#  'eastern-washington',
#  'liberty',
#  'georgia tech',
#  'georgia-tech',
#  'west virginia',
#  'west-virginia',
#  'ucla',
#  'winthrop',
#  'iowa',
#  'villanova',
#  'ohio',
#  'iona',
#  'arkansas',
#  'san diego st',
#  'san diego st.',
#  'san diego state',
#  'san-diego-st',
#  'san-diego-state',
#  'sd state',
#  'oral roberts',
#  'oral-roberts',
#  'ohio st',
#  'ohio st.',
#  'ohio state',
#  'ohio-st',
#  'ohio-state',
#  'georgetown',
#  'tennessee',
#  'wichita st',
#  'wichita st.',
#  'wichita state',
#  'wichita-st',
#  'wichita-state',
#  'wichitastate',
#  'southern california',
#  'southern-california',
#  'usc',
#  'virginia',
#  'north texas',
#  'north-texas',
#  'virginia tech',
#  'virginia-tech',
#  'Mount Saint Mary`s',
#  "mount st. mary's",
#  'mount st. marys',
#  'mount-st-marys',
#  "mt st mary's",
#  "mt st. mary's",
#  'mt-st-marys',
#  "mt. st. mary's",
#  'mt. st. mary`s',
#  'clemson',
#  'drake',
#  'baylor',
#  'florida st',
#  'florida st.',
#  'florida state',
#  'florida-st',
#  'florida-state',
#  'michigan',
#  'cleveland st',
#  'cleveland st.',
#  'cleveland state',
#  'cleveland-st',
#  'cleveland-state',
#  'morehead st',
#  'morehead st.',
#  'morehead state',
#  'morehead-st',
#  'morehead-state',
#  'houston',
#  'california-santa barbara',
#  'california-santa-barbara',
#  'santa barbara',
#  'uc santa barb.',
#  'uc santa barbara',
#  'uc-santa barbara',
#  'uc-santa-barbara',
#  'ucsb',
#  'Saint Bonaventure',
#  'st bonaventure',
#  'st-bonaventure',
#  'st. bonaventure',
#  'norfolk st',
#  'norfolk st.',
#  'norfolk state',
#  'norfolk-st',
#  'norfolk-state',
#  'oregon st',
#  'oregon st.',
#  'oregon state',
#  'oregon-st',
#  'oregon-state',
#  'loyola (il)',
#  'loyola chicago',
#  'loyola-c',
#  'loyola-chicago',
#  'loyola-il',
#  'nc greensboro',
#  'nc-greensboro',
#  'north carolina-greensboro',
#  'north-carolina-greensboro',
#  'unc greensboro',
#  'uncg',
#  'abilene chr',
#  'abilene christian',
#  'abilene-christian',
#  'colgate',
#  'grand canyon',
#  'grand-canyon',
#  'appalachian st',
#  'appalachian st.',
#  'appalachian state',
#  'appalachian-st',
#  'appalachian-state',
#  'rutgers',
#  'drexel',
#  'hartford']

# %%
def get_team_info(yr):
    # get seeds
    seeds_all = pd.read_csv('data/kaggle_data/MNCAATourneySeeds.csv')
    team_spellings = pd.read_csv('data/kaggle_data/MTeamSpellings.csv')
    team_table = seeds_all.merge(team_spellings, on=['TeamID'])
    tourney_team_names = list(team_table[team_table['Season'] == yr]['TeamNameSpelling'])
    link = 'https://www.sports-reference.com/cbb/seasons/' + str(yr) + '-coaches.html'
    with urllib.request.urlopen(link) as url:
        page = url.read()
    soup = BeautifulSoup(page, "html.parser")
    coach_table = soup.find('table', {'id': 'coaches'})
    coach_tbody = coach_table.find('tbody')
    coach_rows = coach_tbody.find_all('tr')
    cols = ['Season','school','returning_min_pct', 'returning_score_pct', 'avg_height', 'avg_yr']
    team_info_df = pd.DataFrame(columns=cols)
    for coach_row in coach_rows:
        tds = coach_row.find_all('td')
        if len(tds) > 10:
            team_stub = tds[0].find('a')['href']
            school = team_stub.split('/')[3]
            if school not in tourney_team_names:
                continue
            team_link = 'https://www.sports-reference.com' + team_stub
            print(school)
            with urllib.request.urlopen(team_link) as url:
                page = url.read()
            team_soup = BeautifulSoup(page, "html.parser")
            text_div = team_soup.find('div', {'id':'tfooter_roster'}).text
            decimals = re.findall('\d+\.\d', text_div)
            if len(decimals) == 3:
                # avg. yr weighted for time played
                year_avg = float(decimals[0])
                returning_min_pct = float(decimals[1])
                returning_score_pct = float(decimals[2])
            else:
                year_avg, returning_min_pct, returning_score_pct = None, None, None
            # avg height
            height_str = re.search('\d+\-+\d', text_div)
            if height_str == None:
                height_avg = 76
            else:
                height_ints = height_str.group().split('-')
                height_avg = 12*int(height_ints[0]) + int(height_ints[1])
                if height_avg > 100:
                    height_avg = 76
            new_row = pd.Series([yr, school, returning_min_pct, returning_score_pct, height_avg, year_avg], index=cols)
            team_info_df = team_info_df.append(new_row, ignore_index=True)
    return(team_info_df)

# %%
get_team_info(2004)
# Out:
#       Season  Seed  TeamID   TeamNameSpelling
# 0       1985   W01    1207         georgetown
# 1       1986   X04    1207         georgetown
# 2       1987   X01    1207         georgetown
# 3       1988   W08    1207         georgetown
# 4       1989   W01    1207         georgetown
# ...      ...   ...     ...                ...
# 6220    2021   X15    1213       grand-canyon
# 6221    2021   Z16    1216           hartford
# 6222    2022   Z14    1255           longwood
# 6223    2022  Z16a    1136             bryant
# 6224    2022  Z16a    1136  bryant university
#
# [6225 rows x 4 columns]
#       Season Seed  TeamID    TeamNameSpelling
# 44      2004  Z03    1210        georgia tech
# 45      2004  Z03    1210        georgia-tech
# 69      2004  W05    1228            illinois
# 140     2004  X05    1393            syracuse
# 203     2004  X07    1177              depaul
# ...      ...  ...     ...                 ...
# 5828    2004  Y15    1186        e washington
# 5829    2004  Y15    1186       eastern wash.
# 5830    2004  Y15    1186  eastern washington
# 5831    2004  Y15    1186        eastern-wash
# 5832    2004  Y15    1186  eastern-washington
#
# [158 rows x 4 columns]
# ['georgia tech', 'georgia-tech', 'illinois', 'syracuse', 'depaul', 'lehigh', 'va commonwealth', 'vcu', 'vcu(va. commonwealth', 'virginia commonwealth', 'virginia-commonwealth', 'n.c. state', 'nc state', 'nc-state', 'north carolina st.', 'north carolina state', 'north-carolina-st', 'north-carolina-state', 'washington', 'alabama', 'arizona', 'texas-el paso', 'texas-el-paso', 'utep', 'kentucky', 'nevada', 'memphis', 'duke', 'texas tech', 'texas-tech', 'alabama-birmingham', 'uab', 'michigan st', 'michigan st.', 'michigan state', 'michigan-st', 'michigan-state', 'boston college', 'boston-college', 'pitt', 'pittsburgh', 'north carolina', 'north-carolina', 'unc', 'kansas', 'maryland', 'dayton', "saint joseph's", 'saint joseph`s', 'saint joseph�s', 'saint-josephs', 'sju (pa)', "st joseph's", "st joseph's pa", 'st-josephs-pa', "st. joseph's", "st. joseph's pa", 'richmond', 'xavier', 'louisville', 'utah', 'florida', 'providence', 'brigham young', 'brigham-young', 'byu', 'vanderbilt', 'murray st', 'murray st.', 'murray state', 'murray-st', 'murray-state', 'charlotte', 'nc charlotte', 'north-carolina-charlotte', 'texas san antonio', 'texas-san antonio', 'texas-san antonio(ut', 'texas-san-antonio', 'ut san antonio', 'utsa', 'seton hall', 'seton-hall', 'stanford', 'south carolina', 'south-carolina', 'princeton', 'texas', 'east tenn. st.', 'east tennessee st.', 'east tennessee state', 'east-tennessee-state', 'etsu', 'connecticut', 'uconn', 'northern iowa', 'northern-iowa', 'uni', 'oklahoma st', 'oklahoma st.', 'oklahoma state', 'oklahoma-st', 'oklahoma-state', 'mississippi st', 'mississippi st.', 'mississippi state', 'mississippi-st', 'mississippi-state', 'wake forest', 'wake-forest', 'la.-lafayette', 'louisiana', 'louisiana-lafayette', 'ull', 'cincinnati', 'manhattan', 's illinois', 'southern ill.', 'southern illinois', 'southern-ill', 'southern-illinois', 'liberty', 'central florida', 'central florida(ucf)', 'central-florida', 'ucf', 'wisconsin', 'gonzaga', 'monmouth', 'monmouth nj', 'monmouth-nj', 'valparaiso', 'pacific', 'il chicago', 'ill-chicago', 'ill.-chicago', 'illinois-chicago', 'uic', 'w michigan', 'western mich.', 'western michigan', 'western-mich', 'western-michigan', 'florida a&m', 'florida-am', 'alabama st', 'alabama st.', 'alabama state', 'alabama-st', 'alabama-state', 'vermont', 'air force', 'air-force', 'e washington', 'eastern wash.', 'eastern washington', 'eastern-wash', 'eastern-washington']
# /cbb/schools/air-force/2004.html
# air-force
# air-force
# /cbb/schools/akron/2004.html
# akron
# /cbb/schools/alabama/2004.html
# alabama
# alabama
# /cbb/schools/alabama-am/2004.html
# alabama-am
# /cbb/schools/alabama-birmingham/2004.html
# alabama-birmingham
# alabama-birmingham
# /cbb/schools/alabama-state/2004.html
# alabama-state
# alabama-state
# /cbb/schools/albany-ny/2004.html
# albany-ny
# /cbb/schools/alcorn-state/2004.html
# alcorn-state
# /cbb/schools/american/2004.html
# american
# /cbb/schools/appalachian-state/2004.html
# appalachian-state
# /cbb/schools/arizona/2004.html
# arizona
# arizona
# /cbb/schools/arizona-state/2004.html
# arizona-state
# /cbb/schools/arkansas/2004.html
# arkansas
# /cbb/schools/arkansas-little-rock/2004.html
# arkansas-little-rock
# /cbb/schools/arkansas-pine-bluff/2004.html
# arkansas-pine-bluff
# /cbb/schools/arkansas-state/2004.html
# arkansas-state
# /cbb/schools/army/2004.html
# army
# /cbb/schools/auburn/2004.html
# auburn
# /cbb/schools/austin-peay/2004.html
# austin-peay
# /cbb/schools/ball-state/2004.html
# ball-state
# /cbb/schools/baylor/2004.html
# baylor
# /cbb/schools/belmont/2004.html
# belmont
# /cbb/schools/bethune-cookman/2004.html
# bethune-cookman
# /cbb/schools/binghamton/2004.html
# binghamton
# /cbb/schools/birmingham-southern/2004.html
# birmingham-southern
# /cbb/schools/boise-state/2004.html
# boise-state
# /cbb/schools/boston-college/2004.html
# boston-college
# boston-college
# /cbb/schools/boston-university/2004.html
# boston-university
# /cbb/schools/bowling-green-state/2004.html
# bowling-green-state
# /cbb/schools/bradley/2004.html
# bradley
# /cbb/schools/brigham-young/2004.html
# brigham-young
# brigham-young
# /cbb/schools/brown/2004.html
# brown
# /cbb/schools/bucknell/2004.html
# bucknell
# /cbb/schools/buffalo/2004.html
# buffalo
# /cbb/schools/butler/2004.html
# butler
# /cbb/schools/cal-poly/2004.html
# cal-poly
# /cbb/schools/cal-state-fullerton/2004.html
# cal-state-fullerton
# /cbb/schools/cal-state-northridge/2004.html
# cal-state-northridge
# /cbb/schools/california/2004.html
# california
# /cbb/schools/california-irvine/2004.html
# california-irvine
# /cbb/schools/california-riverside/2004.html
# california-riverside
# /cbb/schools/california-santa-barbara/2004.html
# california-santa-barbara
# /cbb/schools/campbell/2004.html
# campbell
# /cbb/schools/canisius/2004.html
# canisius
# /cbb/schools/centenary-la/2004.html
# centenary-la
# /cbb/schools/central-connecticut-state/2004.html
# central-connecticut-state
# /cbb/schools/central-florida/2004.html
# central-florida
# central-florida
# /cbb/schools/central-michigan/2004.html
# central-michigan
# /cbb/schools/charleston-southern/2004.html
# charleston-southern
# /cbb/schools/charlotte/2004.html
# charlotte
# charlotte
# /cbb/schools/chattanooga/2004.html
# chattanooga
# /cbb/schools/chicago-state/2004.html
# chicago-state
# /cbb/schools/cincinnati/2004.html
# cincinnati
# cincinnati
# /cbb/schools/citadel/2004.html
# citadel
# /cbb/schools/clemson/2004.html
# clemson
# /cbb/schools/cleveland-state/2004.html
# cleveland-state
# /cbb/schools/coastal-carolina/2004.html
# coastal-carolina
# /cbb/schools/colgate/2004.html
# colgate
# /cbb/schools/college-of-charleston/2004.html
# college-of-charleston
# /cbb/schools/colorado/2004.html
# colorado
# /cbb/schools/colorado-state/2004.html
# colorado-state
# /cbb/schools/columbia/2004.html
# columbia
# /cbb/schools/connecticut/2004.html
# connecticut
# connecticut
# /cbb/schools/coppin-state/2004.html
# coppin-state
# /cbb/schools/cornell/2004.html
# cornell
# /cbb/schools/creighton/2004.html
# creighton
# /cbb/schools/dartmouth/2004.html
# dartmouth
# /cbb/schools/davidson/2004.html
# davidson
# /cbb/schools/dayton/2004.html
# dayton
# dayton
# /cbb/schools/delaware/2004.html
# delaware
# /cbb/schools/delaware-state/2004.html
# delaware-state
# /cbb/schools/denver/2004.html
# denver
# /cbb/schools/depaul/2004.html
# depaul
# depaul
# /cbb/schools/detroit-mercy/2004.html
# detroit-mercy
# /cbb/schools/drake/2004.html
# drake
# /cbb/schools/drexel/2004.html
# drexel
# /cbb/schools/duke/2004.html
# duke
# duke
# /cbb/schools/duquesne/2004.html
# duquesne
# /cbb/schools/east-carolina/2004.html
# east-carolina
# /cbb/schools/east-tennessee-state/2004.html
# east-tennessee-state
# east-tennessee-state
# /cbb/schools/eastern-illinois/2004.html
# eastern-illinois
# /cbb/schools/eastern-kentucky/2004.html
# eastern-kentucky
# /cbb/schools/eastern-michigan/2004.html
# eastern-michigan
# /cbb/schools/eastern-washington/2004.html
# eastern-washington
# eastern-washington
# /cbb/schools/elon/2004.html
# elon
# /cbb/schools/evansville/2004.html
# evansville
# /cbb/schools/fairfield/2004.html
# fairfield
# /cbb/schools/fairleigh-dickinson/2004.html
# fairleigh-dickinson
# /cbb/schools/florida/2004.html
# florida
# florida
# /cbb/schools/florida-am/2004.html
# florida-am
# florida-am
# /cbb/schools/florida-atlantic/2004.html
# florida-atlantic
# /cbb/schools/florida-international/2004.html
# florida-international
# /cbb/schools/florida-state/2004.html
# florida-state
# /cbb/schools/fordham/2004.html
# fordham
# /cbb/schools/fresno-state/2004.html
# fresno-state
# /cbb/schools/furman/2004.html
# furman
# /cbb/schools/gardner-webb/2004.html
# gardner-webb
# /cbb/schools/george-mason/2004.html
# george-mason
# /cbb/schools/george-washington/2004.html
# george-washington
# /cbb/schools/georgetown/2004.html
# georgetown
# /cbb/schools/georgia/2004.html
# georgia
# /cbb/schools/georgia-southern/2004.html
# georgia-southern
# /cbb/schools/georgia-state/2004.html
# georgia-state
# /cbb/schools/georgia-tech/2004.html
# georgia-tech
# georgia-tech
# /cbb/schools/gonzaga/2004.html
# gonzaga
# gonzaga
# /cbb/schools/grambling/2004.html
# grambling
# /cbb/schools/green-bay/2004.html
# green-bay
# /cbb/schools/hampton/2004.html
# hampton
# /cbb/schools/hartford/2004.html
# hartford
# /cbb/schools/harvard/2004.html
# harvard
# /cbb/schools/hawaii/2004.html
# hawaii
# /cbb/schools/high-point/2004.html
# high-point
# /cbb/schools/hofstra/2004.html
# hofstra
# /cbb/schools/holy-cross/2004.html
# holy-cross
# /cbb/schools/houston/2004.html
# houston
# /cbb/schools/howard/2004.html
# howard
# /cbb/schools/idaho/2004.html
# idaho
# /cbb/schools/idaho-state/2004.html
# idaho-state
# /cbb/schools/illinois/2004.html
# illinois
# illinois
# /cbb/schools/illinois-chicago/2004.html
# illinois-chicago
# illinois-chicago
# /cbb/schools/illinois-state/2004.html
# illinois-state
# /cbb/schools/indiana/2004.html
# indiana
# /cbb/schools/indiana-state/2004.html
# indiana-state
# /cbb/schools/iona/2004.html
# iona
# /cbb/schools/iowa/2004.html
# iowa
# /cbb/schools/iowa-state/2004.html
# iowa-state
# /cbb/schools/ipfw/2004.html
# ipfw
# /cbb/schools/iupui/2004.html
# iupui
# /cbb/schools/jackson-state/2004.html
# jackson-state
# /cbb/schools/jacksonville/2004.html
# jacksonville
# /cbb/schools/jacksonville-state/2004.html
# jacksonville-state
# /cbb/schools/james-madison/2004.html
# james-madison
# /cbb/schools/kansas/2004.html
# kansas
# kansas
# /cbb/schools/kansas-state/2004.html
# kansas-state
# /cbb/schools/kent-state/2004.html
# kent-state
# /cbb/schools/kentucky/2004.html
# kentucky
# kentucky
# /cbb/schools/la-salle/2004.html
# la-salle
# /cbb/schools/lafayette/2004.html
# lafayette
# /cbb/schools/lamar/2004.html
# lamar
# /cbb/schools/lehigh/2004.html
# lehigh
# lehigh
# /cbb/schools/liberty/2004.html
# liberty
# liberty
# /cbb/schools/lipscomb/2004.html
# lipscomb
# /cbb/schools/long-beach-state/2004.html
# long-beach-state
# /cbb/schools/long-island-university/2004.html
# long-island-university
# /cbb/schools/louisiana-lafayette/2004.html
# louisiana-lafayette
# louisiana-lafayette
# /cbb/schools/louisiana-monroe/2004.html
# louisiana-monroe
# /cbb/schools/louisiana-state/2004.html
# louisiana-state
# /cbb/schools/louisiana-tech/2004.html
# louisiana-tech
# /cbb/schools/louisville/2004.html
# louisville
# louisville
# /cbb/schools/loyola-il/2004.html
# loyola-il
# /cbb/schools/loyola-marymount/2004.html
# loyola-marymount
# /cbb/schools/loyola-md/2004.html
# loyola-md
# /cbb/schools/maine/2004.html
# maine
# /cbb/schools/manhattan/2004.html
# manhattan
# manhattan
# /cbb/schools/marist/2004.html
# marist
# /cbb/schools/marquette/2004.html
# marquette
# /cbb/schools/marshall/2004.html
# marshall
# /cbb/schools/maryland/2004.html
# maryland
# maryland
# /cbb/schools/maryland-baltimore-county/2004.html
# maryland-baltimore-county
# /cbb/schools/maryland-eastern-shore/2004.html
# maryland-eastern-shore
# /cbb/schools/massachusetts/2004.html
# massachusetts
# /cbb/schools/mcneese-state/2004.html
# mcneese-state
# /cbb/schools/memphis/2004.html
# memphis
# memphis
# /cbb/schools/mercer/2004.html
# mercer
# /cbb/schools/miami-fl/2004.html
# miami-fl
# /cbb/schools/miami-oh/2004.html
# miami-oh
# /cbb/schools/michigan/2004.html
# michigan
# /cbb/schools/michigan-state/2004.html
# michigan-state
# michigan-state
# /cbb/schools/middle-tennessee/2004.html
# middle-tennessee
# /cbb/schools/milwaukee/2004.html
# milwaukee
# /cbb/schools/minnesota/2004.html
# minnesota
# /cbb/schools/mississippi/2004.html
# mississippi
# /cbb/schools/mississippi-state/2004.html
# mississippi-state
# mississippi-state
# /cbb/schools/mississippi-valley-state/2004.html
# mississippi-valley-state
# /cbb/schools/missouri/2004.html
# missouri
# /cbb/schools/missouri-kansas-city/2004.html
# missouri-kansas-city
# /cbb/schools/missouri-state/2004.html
# missouri-state
# /cbb/schools/monmouth/2004.html
# monmouth
# monmouth
# /cbb/schools/montana/2004.html
# montana
# /cbb/schools/montana-state/2004.html
# montana-state
# /cbb/schools/morehead-state/2004.html
# morehead-state
# /cbb/schools/morgan-state/2004.html
# morgan-state
# /cbb/schools/mount-st-marys/2004.html
# mount-st-marys
# /cbb/schools/murray-state/2004.html
# murray-state
# murray-state
# /cbb/schools/navy/2004.html
# navy
# /cbb/schools/nebraska/2004.html
# nebraska
# /cbb/schools/nevada/2004.html
# nevada
# nevada
# /cbb/schools/nevada-las-vegas/2004.html
# nevada-las-vegas
# /cbb/schools/nevada-las-vegas/2004.html
# nevada-las-vegas
# /cbb/schools/new-hampshire/2004.html
# new-hampshire
# /cbb/schools/new-mexico/2004.html
# new-mexico
# /cbb/schools/new-mexico-state/2004.html
# new-mexico-state
# /cbb/schools/new-orleans/2004.html
# new-orleans
# /cbb/schools/niagara/2004.html
# niagara
# /cbb/schools/nicholls-state/2004.html
# nicholls-state
# /cbb/schools/norfolk-state/2004.html
# norfolk-state
# /cbb/schools/north-carolina/2004.html
# north-carolina
# north-carolina
# /cbb/schools/north-carolina-asheville/2004.html
# north-carolina-asheville
# /cbb/schools/north-carolina-at/2004.html
# north-carolina-at
# /cbb/schools/north-carolina-greensboro/2004.html
# north-carolina-greensboro
# /cbb/schools/north-carolina-state/2004.html
# north-carolina-state
# north-carolina-state
# /cbb/schools/north-carolina-wilmington/2004.html
# north-carolina-wilmington
# /cbb/schools/north-texas/2004.html
# north-texas
# /cbb/schools/northeastern/2004.html
# northeastern
# /cbb/schools/northern-arizona/2004.html
# northern-arizona
# /cbb/schools/northern-illinois/2004.html
# northern-illinois
# /cbb/schools/northern-iowa/2004.html
# northern-iowa
# northern-iowa
# /cbb/schools/northwestern/2004.html
# northwestern
# /cbb/schools/northwestern-state/2004.html
# northwestern-state
# /cbb/schools/notre-dame/2004.html
# notre-dame
# /cbb/schools/oakland/2004.html
# oakland
# /cbb/schools/ohio/2004.html
# ohio
# /cbb/schools/ohio-state/2004.html
# ohio-state
# /cbb/schools/oklahoma/2004.html
# oklahoma
# /cbb/schools/oklahoma-state/2004.html
# oklahoma-state
# oklahoma-state
# /cbb/schools/old-dominion/2004.html
# old-dominion
# /cbb/schools/oral-roberts/2004.html
# oral-roberts
# /cbb/schools/oregon/2004.html
# oregon
# /cbb/schools/oregon-state/2004.html
# oregon-state
# /cbb/schools/pacific/2004.html
# pacific
# pacific
# /cbb/schools/penn-state/2004.html
# penn-state
# /cbb/schools/pennsylvania/2004.html
# pennsylvania
# /cbb/schools/pepperdine/2004.html
# pepperdine
# /cbb/schools/pittsburgh/2004.html
# pittsburgh
# pittsburgh
# /cbb/schools/portland/2004.html
# portland
# /cbb/schools/portland-state/2004.html
# portland-state
# /cbb/schools/prairie-view/2004.html
# prairie-view
# /cbb/schools/princeton/2004.html
# princeton
# princeton
# /cbb/schools/providence/2004.html
# providence
# providence
# /cbb/schools/purdue/2004.html
# purdue
# /cbb/schools/quinnipiac/2004.html
# quinnipiac
# /cbb/schools/radford/2004.html
# radford
# /cbb/schools/rhode-island/2004.html
# rhode-island
# /cbb/schools/rice/2004.html
# rice
# /cbb/schools/richmond/2004.html
# richmond
# richmond
# /cbb/schools/rider/2004.html
# rider
# /cbb/schools/robert-morris/2004.html
# robert-morris
# /cbb/schools/rutgers/2004.html
# rutgers
# /cbb/schools/sacramento-state/2004.html
# sacramento-state
# /cbb/schools/sacred-heart/2004.html
# sacred-heart
# /cbb/schools/saint-francis-pa/2004.html
# saint-francis-pa
# /cbb/schools/saint-josephs/2004.html
# saint-josephs
# saint-josephs
# /cbb/schools/saint-louis/2004.html
# saint-louis
# /cbb/schools/saint-marys-ca/2004.html
# saint-marys-ca
# /cbb/schools/saint-peters/2004.html
# saint-peters
# /cbb/schools/sam-houston-state/2004.html
# sam-houston-state
# /cbb/schools/samford/2004.html
# samford
# /cbb/schools/san-diego/2004.html
# san-diego
# /cbb/schools/san-diego-state/2004.html
# san-diego-state
# /cbb/schools/san-francisco/2004.html
# san-francisco
# /cbb/schools/san-jose-state/2004.html
# san-jose-state
# /cbb/schools/santa-clara/2004.html
# santa-clara
# /cbb/schools/savannah-state/2004.html
# savannah-state
# /cbb/schools/seton-hall/2004.html
# seton-hall
# seton-hall
# /cbb/schools/siena/2004.html
# siena
# /cbb/schools/south-alabama/2004.html
# south-alabama
# /cbb/schools/south-carolina/2004.html
# south-carolina
# south-carolina
# /cbb/schools/south-carolina-state/2004.html
# south-carolina-state
# /cbb/schools/south-florida/2004.html
# south-florida
# /cbb/schools/southeast-missouri-state/2004.html
# southeast-missouri-state
# /cbb/schools/southeastern-louisiana/2004.html
# southeastern-louisiana
# /cbb/schools/southern/2004.html
# southern
# /cbb/schools/southern-california/2004.html
# southern-california
# /cbb/schools/southern-illinois/2004.html
# southern-illinois
# southern-illinois
# /cbb/schools/southern-methodist/2004.html
# southern-methodist
# /cbb/schools/southern-mississippi/2004.html
# southern-mississippi
# /cbb/schools/southern-utah/2004.html
# southern-utah
# /cbb/schools/st-bonaventure/2004.html
# st-bonaventure
# /cbb/schools/st-francis-ny/2004.html
# st-francis-ny
# /cbb/schools/st-johns-ny/2004.html
# st-johns-ny
# /cbb/schools/st-johns-ny/2004.html
# st-johns-ny
# /cbb/schools/stanford/2004.html
# stanford
# stanford
# /cbb/schools/stephen-f-austin/2004.html
# stephen-f-austin
# /cbb/schools/stetson/2004.html
# stetson
# /cbb/schools/stony-brook/2004.html
# stony-brook
# /cbb/schools/syracuse/2004.html
# syracuse
# syracuse
# /cbb/schools/temple/2004.html
# temple
# /cbb/schools/tennessee/2004.html
# tennessee
# /cbb/schools/tennessee-martin/2004.html
# tennessee-martin
# /cbb/schools/tennessee-state/2004.html
# tennessee-state
# /cbb/schools/tennessee-tech/2004.html
# tennessee-tech
# /cbb/schools/texas/2004.html
# texas
# texas
# /cbb/schools/texas-am/2004.html
# texas-am
# /cbb/schools/texas-am-corpus-christi/2004.html
# texas-am-corpus-christi
# /cbb/schools/texas-arlington/2004.html
# texas-arlington
# /cbb/schools/texas-christian/2004.html
# texas-christian
# /cbb/schools/texas-el-paso/2004.html
# texas-el-paso
# texas-el-paso
# /cbb/schools/texas-pan-american/2004.html
# texas-pan-american
# /cbb/schools/texas-san-antonio/2004.html
# texas-san-antonio
# texas-san-antonio
# /cbb/schools/texas-southern/2004.html
# texas-southern
# /cbb/schools/texas-state/2004.html
# texas-state
# /cbb/schools/texas-tech/2004.html
# texas-tech
# texas-tech
# /cbb/schools/toledo/2004.html
# toledo
# /cbb/schools/towson/2004.html
# towson
# /cbb/schools/troy/2004.html
# troy
# /cbb/schools/tulane/2004.html
# tulane
# /cbb/schools/tulsa/2004.html
# tulsa
# /cbb/schools/ucla/2004.html
# ucla
# /cbb/schools/utah/2004.html
# utah
# utah
# /cbb/schools/utah/2004.html
# utah
# utah
# /cbb/schools/utah-state/2004.html
# utah-state
# /cbb/schools/valparaiso/2004.html
# valparaiso
# valparaiso
# /cbb/schools/vanderbilt/2004.html
# vanderbilt
# vanderbilt
# /cbb/schools/vermont/2004.html
# vermont
# vermont
# /cbb/schools/villanova/2004.html
# villanova
# /cbb/schools/virginia/2004.html
# virginia
# /cbb/schools/virginia-commonwealth/2004.html
# virginia-commonwealth
# virginia-commonwealth
# /cbb/schools/virginia-military-institute/2004.html
# virginia-military-institute
# /cbb/schools/virginia-tech/2004.html
# virginia-tech
# /cbb/schools/wagner/2004.html
# wagner
# /cbb/schools/wake-forest/2004.html
# wake-forest
# wake-forest
# /cbb/schools/washington/2004.html
# washington
# washington
# /cbb/schools/washington-state/2004.html
# washington-state
# /cbb/schools/weber-state/2004.html
# weber-state
# /cbb/schools/west-virginia/2004.html
# west-virginia
# /cbb/schools/western-carolina/2004.html
# western-carolina
# /cbb/schools/western-illinois/2004.html
# western-illinois
# /cbb/schools/western-kentucky/2004.html
# western-kentucky
# /cbb/schools/western-michigan/2004.html
# western-michigan
# western-michigan
# /cbb/schools/wichita-state/2004.html
# wichita-state
# /cbb/schools/william-mary/2004.html
# william-mary
# /cbb/schools/winthrop/2004.html
# winthrop
# /cbb/schools/wisconsin/2004.html
# wisconsin
# wisconsin
# /cbb/schools/wofford/2004.html
# wofford
# /cbb/schools/wright-state/2004.html
# wright-state
# /cbb/schools/wyoming/2004.html
# wyoming
# /cbb/schools/xavier/2004.html
# xavier
# xavier
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-a8b0b43e7279> in <module>
# ----> 1 get_team_info(2004)
#
# <ipython-input-57-30890caa4f75> in get_team_info(yr)
#      31             with urllib.request.urlopen(team_link) as url:
#      32                 page = url.read()
# ---> 33             team_soup = BeautifulSoup(page, "html.parser")
#      34             text_div = team_soup.find('div', {'id':'tfooter_roster'}).text
#      35             decimals = re.findall('\d+\.\d', text_div)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     346             self.reset()
#     347             try:
# --> 348                 self._feed()
#     349                 success = True
#     350                 break
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in _feed(self)
#     432         self.builder.reset()
#     433
# --> 434         self.builder.feed(self.markup)
#     435         # Close out any unfinished strings and close all the open tags.
#     436         self.endData()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     375         parser.soup = self.soup
#     376         try:
# --> 377             parser.feed(markup)
#     378             parser.close()
#     379         except HTMLParseError as e:
#
# ~/opt/anaconda3/lib/python3.8/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/html/parser.py in goahead(self, end)
#     197                     else:
#     198                         self.handle_data(rawdata[i:k])
# --> 199                 i = self.updatepos(i, k)
#     200             elif startswith("&#", i):
#     201                 match = charref.match(rawdata, i)
#
# ~/opt/anaconda3/lib/python3.8/_markupbase.py in updatepos(self, i, j)
#      56             self.offset = j-(pos+1)
#      57         else:
# ---> 58             self.offset = self.offset + j-i
#      59         return j
#      60
#
# KeyboardInterrupt:

# %%
def sports_ref_join_to_kaggle(coach_df):
    team_spellings = pd.read_csv('data/kaggle_data/MTeamSpellings.csv')
    coach_joined = team_spellings.merge(coach_df, left_on='TeamNameSpelling', right_on='school')
    coach_joined.drop('TeamNameSpelling', axis=1, inplace=True)
    return(coach_joined)

# %%
team_info_df = get_team_info(2022)
team_info_joined = sports_ref_join_to_kaggle(team_info_df)
for yr in range(2021,2002,-1):
    print(yr)
    new_team_info_df = get_team_info(yr)
    new_team_info_joined = sports_ref_join_to_kaggle(new_team_info_df)
    team_info_joined = pd.concat([team_info_joined, new_team_info_joined], ignore_index=True)
# Out:
# akron
# alabama
# alabama-birmingham
# arizona
# arkansas
# auburn
# baylor
# boise-state
# bryant
# cal-state-fullerton
# chattanooga
# colgate
# colorado-state
# connecticut
# creighton
# davidson
# delaware
# duke
# georgia-state
# gonzaga
# houston
# illinois
# indiana
# iowa
# iowa-state
# jacksonville-state
# kansas
# kentucky
# longwood
# louisiana-state
# louisiana-state
# loyola-il
# marquette
# memphis
# miami-fl
# michigan
# michigan-state
# montana-state
# murray-state
# new-mexico-state
# norfolk-state
# north-carolina
# notre-dame
# ohio-state
# providence
# purdue
# richmond
# rutgers
# saint-marys-ca
# saint-peters
# san-diego-state
# san-francisco
# seton-hall
# south-dakota-state
# southern-california
# tennessee
# texas
# texas-am-corpus-christi
# texas-christian
# texas-southern
# texas-tech
# ucla
# vermont
# villanova
# virginia-tech
# wisconsin
# wright-state
# wyoming
# yale
# 2021
# abilene-christian
# alabama
# appalachian-state
# arkansas
# baylor
# brigham-young
# california-santa-barbara
# clemson
# cleveland-state
# colgate
# colorado
# connecticut
# creighton
# drake
# drexel
# eastern-washington
# florida
# florida-state
# georgetown
# georgia-tech
# gonzaga
# grand-canyon
# hartford
# houston
# illinois
# iona
# iowa
# kansas
# liberty
# louisiana-state
# loyola-il
# maryland
# michigan
# michigan-state
# missouri
# morehead-state
# mount-st-marys
# norfolk-state
# north-carolina
# north-carolina-greensboro
# north-texas
# ohio
# ohio-state
# oklahoma
# oklahoma-state
# oral-roberts
# oregon
# oregon-state
# purdue
# rutgers
# san-diego-state
# southern-california
# st-bonaventure
# syracuse
# tennessee
# texas
# texas-southern
# texas-tech
# ucla
# utah-state
# villanova
# virginia
# virginia-commonwealth
# virginia-tech
# west-virginia
# wichita-state
# winthrop
# wisconsin
# 2020
# 2019
# abilene-christian
# arizona-state
# auburn
# baylor
# belmont
# bradley
# buffalo
# california-irvine
# central-florida
# cincinnati
# colgate
# duke
# fairleigh-dickinson
# florida
# florida-state
# gardner-webb
# georgia-state
# gonzaga
# houston
# iona
# iowa
# iowa-state
# kansas
# kansas-state
# kentucky
# liberty
# louisiana-state
# louisville
# marquette
# maryland
# michigan
# michigan-state
# connecticut
# creighton
# delaware-state
# duke
# eastern-kentucky
# fairleigh-dickinson
# florida
# george-washington
# georgia-tech
# gonzaga
# illinois
# iowa
# iowa-state
# kansas
# kentucky
# louisiana-lafayette
# louisiana-state
# louisville
# michigan-state
# milwaukee
# minnesota
# mississippi-state
# montana
# nevada
# new-mexico
# niagara
# north-carolina
# north-carolina-state
# northern-iowa
# oakland
# ohio
# oklahoma
# oklahoma-state
# old-dominion
# pacific
# pennsylvania
# pittsburgh
# saint-marys-ca
# southeastern-louisiana
# southern-illinois
# stanford
# syracuse
# texas
# texas-el-paso
# texas-tech
# ucla
# utah
# utah-state
# vermont
# villanova
# wake-forest
# washington
# west-virginia
# winthrop
# wisconsin
# 2004
# air-force
# alabama
# alabama-birmingham
# alabama-state
# arizona
# boston-college
# brigham-young
# central-florida
# charlotte
# cincinnati
# connecticut
# dayton
# depaul
# duke
# east-tennessee-state
# eastern-washington
# florida
# florida-am
# georgia-tech
# gonzaga
# illinois
# illinois-chicago
# kansas
# kentucky
# lehigh
# liberty
# louisiana-lafayette
# louisville
# manhattan
# maryland
# memphis
# michigan-state
# mississippi-state
# monmouth
# murray-state
# nevada
# north-carolina
# north-carolina-state
# northern-iowa
# oklahoma-state
# pacific
# pittsburgh
# princeton
# providence
# richmond
# saint-josephs
# seton-hall
# south-carolina
# southern-illinois
# stanford
# syracuse
# texas
# texas-el-paso
# texas-san-antonio
# texas-tech
# utah
# utah
# valparaiso
# vanderbilt
# vermont
# virginia-commonwealth
# wake-forest
# washington
# western-michigan
# wisconsin
# xavier
# 2003
# alabama
# arizona
# arizona-state
# auburn
# austin-peay
# brigham-young
# butler
# california
# central-michigan
# cincinnati
# colorado
# colorado-state
# connecticut
# creighton
# dayton
# duke
# east-tennessee-state
# florida
# gonzaga
# holy-cross
# illinois
# indiana
# iupui
# kansas
# kentucky
# louisiana-state
# louisville
# manhattan
# marquette
# maryland
# memphis
# michigan-state
# milwaukee
# mississippi-state
# missouri
# north-carolina-asheville
# north-carolina-state
# north-carolina-wilmington
# notre-dame
# oklahoma
# oklahoma-state
# oregon
# pennsylvania
# pittsburgh
# purdue
# saint-josephs
# sam-houston-state
# san-diego
# south-carolina-state
# southern-illinois
# stanford
# syracuse
# texas
# texas-southern
# troy
# tulsa
# utah
# utah-state
# vermont
# wagner
# wake-forest
# weber-state
# western-kentucky
# wisconsin
# xavier

# %%
team_info_joined
# Out:
#       TeamID Season              school returning_min_pct returning_score_pct  \
# 0       1103   2022               akron              60.1                53.1
# 1       1104   2022             alabama              46.6                49.3
# 2       1412   2022  alabama-birmingham              60.0                63.2
# 3       1112   2022             arizona              48.3                45.9
# 4       1116   2022            arkansas              37.5                37.4
# ...      ...    ...                 ...               ...                 ...
# 1269    1448   2003         wake-forest              39.3                37.3
# 1270    1451   2003         weber-state              83.6                82.6
# 1271    1443   2003    western-kentucky              71.8                77.7
# 1272    1458   2003           wisconsin              66.5                72.1
# 1273    1462   2003              xavier              73.7                81.1
#
#      avg_height avg_yr
# 0            76    2.2
# 1            77    1.3
# 2            77    3.1
# 3            80    1.5
# 4            77    2.5
# ...         ...    ...
# 1269         76    1.0
# 1270         77    2.0
# 1271         77    1.7
# 1272         77    1.2
# 1273         77    1.3
#
# [1274 rows x 7 columns]

# %%
team_info_joined.groupby('Season').count()
# Out:
#         TeamID  school  returning_min_pct  returning_score_pct  avg_height  \
# Season
# 2003        65      65                 59                   59          65
# 2004        66      66                 65                   65          66
# 2005        65      65                 65                   65          65
# 2006        65      65                 65                   65          65
# 2007        65      65                 63                   63          65
# 2008        66      66                 65                   65          66
# 2009        65      65                 63                   63          65
# 2010        65      65                 65                   65          65
# 2011        68      68                 68                   68          68
# 2012        69      69                 69                   69          69
# 2013        68      68                 68                   68          68
# 2014        68      68                 68                   68          68
# 2015        68      68                 68                   68          68
# 2016        70      70                 70                   70          70
# 2017        68      68                 68                   68          68
# 2018        68      68                 68                   68          68
# 2019        68      68                 68                   68          68
# 2021        68      68                 68                   68          68
# 2022        69      69                 68                   68          69
#
#         avg_yr
# Season
# 2003        59
# 2004        65
# 2005        65
# 2006        65
# 2007        63
# 2008        65
# 2009        63
# 2010        65
# 2011        68
# 2012        69
# 2013        68
# 2014        68
# 2015        68
# 2016        70
# 2017        68
# 2018        68
# 2019        68
# 2021        68
# 2022        68

# %%
team_info_joined.to_csv('data/generated_data/additional_team_features.csv', index=False)

# %%
def check_for_missing_spellings(df, joined):
    comp = df.merge(joined, on='TeamID', how='left')
    return(comp[comp['school'].isna()])

# %%
seeds = seeds_all[seeds_all['Season'] >= 2009]

# %%
seeds.merge(team_info_joined, on='TeamID', how='left')
# Out:
#       Season_x  Seed  TeamID Season_y        school returning_min_pct  \
# 0         2009   W01    1338     2016    pittsburgh              73.0
# 1         2009   W01    1338     2014    pittsburgh              50.7
# 2         2009   W01    1338     2013    pittsburgh              57.6
# 3         2009   W01    1338     2011    pittsburgh              84.3
# 4         2009   W01    1338     2010    pittsburgh              42.5
# ...        ...   ...     ...      ...           ...               ...
# 5460      2022   Z15    1174     2022      delaware             100.0
# 5461      2022   Z15    1174     2014      delaware              62.4
# 5462      2022  Z16a    1136     2022        bryant              75.4
# 5463      2022  Z16b    1460     2022  wright-state              73.2
# 5464      2022  Z16b    1460     2018  wright-state              53.2
#
#      returning_score_pct avg_height avg_yr
# 0                   76.5         79    2.1
# 1                   48.8         78    1.8
# 2                   56.3         78    1.9
# 3                   86.0         77    2.3
# 4                   33.4         76    1.4
# ...                  ...        ...    ...
# 5460               100.0         77    2.4
# 5461                67.1         77    1.7
# 5462                76.8         77    2.4
# 5463                68.5         77    1.8
# 5464                44.1         77    1.4
#
# [5465 rows x 9 columns]

# %%
check_for_missing_spellings(seeds, team_info_joined)
# Out:
# Empty DataFrame
# Columns: [Season_x, Seed, TeamID, Season_y, school, returning_min_pct, returning_score_pct, avg_height, avg_yr]
# Index: []
